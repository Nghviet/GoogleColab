# %%
# !pip install kaggle
# !mkdir -p ~/.kaggle
# !cp "/content/drive/My Drive/kaggle.json" ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle competitions download -c student-shopee-code-league-sentiment-analysis
# !unzip test.csv.zip
# !unzip train.csv.zip
# Out:
# ...
#   0% 0.00/2.22M [00:00<?, ?B/s]
# 100% 2.22M/2.22M [00:00<00:00, 73.4MB/s]
# ...
# 100% 4.78M/4.78M [00:00<00:00, 18.0MB/s]
#
# ...
#   0% 0.00/63.0 [00:00<?, ?B/s]
# 100% 63.0/63.0 [00:00<00:00, 56.5kB/s]
# Archive:  test.csv.zip
#   inflating: test.csv
# Archive:  train.csv.zip
#   inflating: train.csv

# %%
import tensorflow as tf
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
import json
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

df = pd.read_csv('/content/train.csv').drop(['review_id'],axis = 1)
test = pd.read_csv('/content/test.csv')
df

def data_prep(text):
  

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline

text = df.review.to_numpy()
label = df.rating.to_numpy()
model = make_pipeline(TfidfVectorizer(), MultinomialNB())

model.fit(text,label)
model
testLabel = model.predict(test.review.to_numpy())

data = {
    'review_id' : test.review_id.to_numpy(),
    'rating'    : testLabel
}

submit = pd.DataFrame(data)
submit.to_csv('/content/submit.csv',index = False)
print(submit)
print(test)
# Out:
#        review_id  rating
# 0              1       3
# 1              2       3
# 2              3       5
# 3              4       4
# 4              5       4
# ...          ...     ...
# 60422      60423       5
# 60423      60424       3
# 60424      60425       5
# 60425      60426       4
# 60426      60427       5
#
# [60427 rows x 2 columns]
#        review_id                                             review
# 0              1  Great danger, cool, motif and cantik2 jg model...
# 1              2                   One of the shades don't fit well
# 2              3                                   Very comfortable
# 3              4  Fast delivery. Product expiry is on Dec 2022. ...
# 4              5  it's sooooo cute! i like playing with the glit...
# ...          ...                                                ...
# 60422      60423  Product has been succesfully ordered and shipp...
# 60423      60424  Opening time a little scared. Fear dalemnya de...
# ...

# %%
# !kaggle competitions submit -c student-shopee-code-league-sentiment-analysis -f submit.csv -m "Viet - Naive_Bayes"
# Out:
# ...
# 100% 461k/461k [00:01<00:00, 405kB/s]
# Successfully submitted to [Student] Shopee Code League - Sentiment Analysis
