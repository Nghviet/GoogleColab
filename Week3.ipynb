# %%
# !pip install kaggle
# !mkdir -p ~/.kaggle
# !cp "/content/drive/My Drive/kaggle.json" ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle competitions download -c student-shopee-code-league-product-translation
# !unzip train_en.csv.zip
# !unzip train_tcn.csv.zip
